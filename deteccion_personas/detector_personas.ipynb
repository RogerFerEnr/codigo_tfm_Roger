# %% [markdown]
# #### Vamos a entrenar un detector de personas usando yolov5. Para ello, a partir del dataset de coco. En primer lugar extraemos las imágenes y las anotaciones de los bounding boxes del dataset de Coco para la clase persona

# %% [markdown]
# #### Usamos el repositorio de github de yolov5 para realizar la detección
#
# ##### Debemos configurar un entrono virtual de trabajo.
# ##### Creamos un entorno conda create -n entonoYolo python = 3.8
# ##### Activamos el entorno conda activate entornoYolo
# ##### Nos desplazamos a la carpeta de trabajo
# ##### Clonamos el entorno de trabajo de yolov5: https://github.com/ultralytics/yolov5.git
#
# ##### Nos desplazamos a la carpeta de yolov5: cd yolov5
# ##### Instalamos las dependencias necesarias para instalar yolov5: pip install - requirements.txt
# ##### Falta la librería typeguard (da error al ejecutar el comando anterior) pip install typeguard
# ##### Instalamos jupyter-notebooks: pip install jupyter
#
# ##### Con esta configuración estamos listos ya para usar yolov5

# %% [markdown]
# #### Importamos las bibliotecas que sean necesarias

# %%
from pycocotools.coco import COCO #Nos va a servir para cargar las imágenes y las anotaciones de bounding box para la clase persona
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import torch

import shutil

# %% [markdown]
# #### Hacemos git clone del repositorio de github de yolov5

# %%
#!git clone --recursive https://github.com/ultralytics/yolov5.git

# %% [markdown]
# ##### Se comprueba que la tarjeta gráfica está disponible en el entorno para la realización del entrenamiento.

# %%
print(f"Carga completada. Estamos usando torch version {torch.__version__}")
print(f"GPU disponible: {torch.cuda.is_available()}")
# Out:
# Carga completada. Estamos usando torch version 2.3.0+cu121
# GPU disponible: True

# %% [markdown]
# #### Creamos los directorios necesarios para almacenar las imágenes y las anotaciones para yolo.

# %%
ruta_actual = os.getcwd()
ruta_yolov5 = os.path.join(ruta_actual,"yolov5")
ruta_datos_entrenamiento_validacion = os.path.join(ruta_yolov5,"datos_deteccion_personas")

#Creamos la carpeta datos_deteccion_caras dentro de la carpeta de yolov5 (se obtuvo al hacer el git clone del repositorio de github)
try:
  os.mkdir(ruta_datos_entrenamiento_validacion)
except:
  print("EL directorio ya existe")

# %%
ruta_imagenes = os.path.join(ruta_datos_entrenamiento_validacion,"images")
try:
  os.mkdir(ruta_imagenes)
except:
  print("El directorio imágenes ya existe")

ruta_imagenes_entrenamiento = os.path.join(ruta_imagenes,"train") 
try:
  os.mkdir(ruta_imagenes_entrenamiento)
except:
  print("El directorio de imágenes de entrenamiento ya existe")

ruta_imagenes_validacion = os.path.join(ruta_imagenes,"val")
try:
  os.mkdir(ruta_imagenes_validacion)
except:
  print("El directorio de imágenes validacion ya existe")


ruta_etiquetas = os.path.join(ruta_datos_entrenamiento_validacion,"labels")
try:
  os.mkdir(ruta_etiquetas)
except:
  print("El directorio etiquetas ya existe")

ruta_etiquetas_entrenamiento = os.path.join(ruta_etiquetas,"train")
try:
  os.mkdir(ruta_etiquetas_entrenamiento)
except:
  print("El directorio etiquetas de entrenamiento ya existe")

ruta_etiquetas_validacion = os.path.join(ruta_etiquetas,"val")
try:
  os.mkdir(ruta_etiquetas_validacion)
except:
  print("El directorio etiquetas de validación ya existe")

# %% [markdown]
# #### Creamos una función para transformar los datos de las bounding boxes a formato Yolo.

# %%
#Creamos una función que pasa las anotaciones de wider dataset al formato de yolo
def caja_yolo(x_esquina_superior,y_esquina_superior,ancho_bb,alto_bb,ruta_imagen):

    #no hace falta realizar el casting
    #x_esquina_superior = int(x_esquina_superior)
    #y_esquina_superior = int(y_esquina_superior)
    #ancho_bb = int(ancho_bb)
    #alto_bb = int(alto_bb)
        
    imagen = cv2.imread(ruta_imagen)
    filas,columnas,_ = imagen.shape
    x = (x_esquina_superior + ancho_bb/2)/columnas
    y = (y_esquina_superior + alto_bb/2)/filas 
    w = ancho_bb/columnas
    h = alto_bb/filas
    return x,y,w,h

# %% [markdown]
# #### Usamos la API de coco para seleccionar las imágenes de personas y las anotaciones para las bounding boxes.
# #### Creamos una función que realiza el proceso

# %%
# Ruta a los archivo de anotaciones de Coco
ruta_anotaciones_entrenamiento = '/media/roger/Datos/asignaturas_master/tfm/coco_dataset/annotations_trainval2017/annotations/instances_train2017.json'
ruta_anotaciones_validacion = '/media/roger/Datos/asignaturas_master/tfm/coco_dataset/annotations_trainval2017/annotations/instances_val2017.json'

numero_anotaciones_entrenamiento = 0
numero_anotaciones_validacion = 0



def crear_anotaciones(ruta_anotaciones):
    global numero_anotaciones_entrenamiento
    global numero_anotaciones_validacion

    # Cargar anotaciones de coco
    anotaciones_coco = COCO(ruta_anotaciones)

    #Obtenemos la categoría ID para la clase personas
    categoria_persona = anotaciones_coco.getCatIds(catNms=['person'])

    print(categoria_persona)

    #El id para la categoría persona es el número 1. Obtenemos todas las imágenes en las que aparecen personas, así como las bounding boxes.
    # Obtenemos todas los ids/números de imagenes relativos a personas
    id_imagenes_personas = anotaciones_coco.getImgIds(catIds=categoria_persona)
    #obtenemos una lista de números naturales que hacen referencias a personas.
    #Las imágenes tienen el nombre 000000numero.jpg donde número es alguno de los números de la lista (12 dígitos en total)


    info_general_imagenes_personas = anotaciones_coco.loadImgs(id_imagenes_personas)

    # Guardamos las imágenes y los txt con las anotaciones en la estructura de carpetas de yolo


    for info_imagen in info_general_imagenes_personas:

    
        ruta_dataset_coco = "/media/roger/Datos/asignaturas_master/tfm/coco_dataset"

        nombre_imagen = info_imagen['file_name']
        url = info_imagen['coco_url']
        ruta_relativa = os.path.join(*url.split('/')[-2:])
        tipo_entrenamiento_validacion = os.path.join(*url.split('/')[-2:-1])
        #ancho_imagen = info_imagen['width']
        #alto_imagen = info_imagen['height']
        ruta_imagen = os.path.join(ruta_dataset_coco,ruta_relativa)

        #Guardamos la imagen en el directorio adecuado. Creamos el txt en el directorio adecuado
        if tipo_entrenamiento_validacion == "train2017":
            #Copiamos imagen de entrenamiento al directorio adecuado de yolo
            shutil.copy(ruta_imagen,ruta_imagenes_entrenamiento)
            #Creamos el txt con las anotaciones de entrenamiento en el directorio adecuado de yolo
            nombre_txt = os.path.basename(nombre_imagen.strip())[:-3] + 'txt'
            txt = os.path.join(ruta_etiquetas_entrenamiento, nombre_txt)
    
        elif tipo_entrenamiento_validacion == "val2017":
            #Copiamos la imagen de validación al directorio adecuado de yolo
            shutil.copy(ruta_imagen,ruta_imagenes_validacion)
            #Creamos el txt con las anotaciones de validación en el directorio adecuado de yolo
            nombre_txt = os.path.basename(nombre_imagen.strip())[:-3] + 'txt'
            txt = os.path.join(ruta_etiquetas_validacion, nombre_txt)
        
        else:
            print("Hubo un error. La imagen no pertenece ni a train ni a val")
    
        #Obtenemos las anotaciones para las imágenes. En particular sólo tomaremos las bounding boxes ya que sólo esos datos nos interesan
        imagen_id = info_imagen['id']    

        anotaciones_ids = anotaciones_coco.getAnnIds(imgIds=imagen_id, catIds=categoria_persona, iscrowd=None)
        anotaciones_personas_imagen = anotaciones_coco.loadAnns(anotaciones_ids)    

        #recorremos con el bucle for todas las anotaciones y tomamos las relativas a los bounding box
        #Grabamos las anotaciones en txt en los directorios adecuados

        #Primero abrimos el txt
        archivo_txt = open(txt,"a")
        for anotacion in anotaciones_personas_imagen:
        
            #Incrementamos en uno el contador de anotaciones
            if tipo_entrenamiento_validacion == "train2017":
                numero_anotaciones_entrenamiento += 1
            elif tipo_entrenamiento_validacion == "val2017":
                numero_anotaciones_validacion += 1
            else:
                print("Hubo un error. La imagen no pertenece ni a train ni a val")
        
            bounding_box = anotacion['bbox']
            x,y,w,h = bounding_box

            #Procesamos los bounding box y los transformamos al formato yolo
            x,y,w,h = caja_yolo(x,y,w,h,ruta_imagen)
        
            #Grabamos las anotaciones en formato yolo en el txt
            archivo_txt.write(str(0) + " ")
            archivo_txt.write(str(x) + " ")
            archivo_txt.write(str(y) + " ")
            archivo_txt.write(str(w) + " ")
            archivo_txt.write(str(h))
            archivo_txt.write("\n")
    
        #Una vez grabadas las anotaciones, cerramos el txt
        archivo_txt.close()

# %% [markdown]
# #### Generamos anotaciones e imágenes de entrenamiento

# %%
crear_anotaciones(ruta_anotaciones_entrenamiento)
# Out:
# loading annotations into memory...
# Done (t=6.75s)
# creating index...
# index created!
# [1]

# %% [markdown]
# #### Generamos anotaciones e imágenes de validación

# %%
crear_anotaciones(ruta_anotaciones_validacion)
# Out:
# loading annotations into memory...
# Done (t=0.20s)
# creating index...
# index created!
# [1]

# %% [markdown]
# #### Mostramos la información de imágenes y las anotaciones en entrenamiento y test

# %%
print(f"El número de imágenes de entrenamiento es {len(os.listdir(ruta_imagenes_entrenamiento))} con un total de {numero_anotaciones_entrenamiento} anotaciones")

print(f"El número de imágenes de validación es {len(os.listdir(ruta_imagenes_validacion))} con un total de {numero_anotaciones_validacion} anotaciones")
# Out:
# El número de imágenes de entrenamiento es 64115 con un total de 262465 anotaciones
# El número de imágenes de validación es 2693 con un total de 11004 anotaciones

# %% [markdown]
# #### Entrenamos el modelo durante 75 épocas usando el script train.py del repositorio de github de yolov5. En mi caso usé la opción --cache para acelerar el entrenamiento (esto sólo debe hacerse si se dispone de una memoria ram grande que sea capaz de almacenar todas las imágenes de entrenamiento y validación en memoria ram). El batch se tomo de 8 (es adecuado para mi GPU con 8 GB de VRAM)
#
# #### En la carpeta  se almacena información del entrenamiento y datos sobre el conjunto de validación. En la carpeta weights dentro del directorio yolov5/runs/train se almacenan los pesos del último modelo y del mejor modelo resultado del entrenamiento. en results.csv se almacenan datos de cada época de entrenamiento. Aparecen también gráficas de entrenamiento (matrtiz de confusión, curva F1, curva precision/recall, etc)

# %%
#Probamos con un modelo intermedio yolov5m (detectar personas es más fácil que detectar caras). Puede verse en https://github.com/ultralytics/yolov5
# !python ./yolov5/train.py --batch 16 --epochs 50 --patience 10 --data ./yolov5/data/custom.yaml --weights yolov5m.pt --cache

#Probamos con un tamaño de lote grande (32) (32 es demasiado batch-size) porque el modelo es más ligero que otros (21  millones de parámetros)
#Usar un modelo más pequeño puede beneficiar el entrenamiento ya que tenemos muchas imágenes etiquetadas 
#No pude meter las imágenes en cache porque son demasiadas. Intentamos entrenar 50 época.
#Puede que considere la posibilidad de reducir el tamaño del dataset.
# Out:
# train: weights=yolov5m.pt, cfg=, data=./yolov5/data/custom.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=10, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-353-g5eca7b9c Python-3.10.13 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7940MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     24246  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model summary: 291 layers, 20871318 parameters, 20871318 gradients, 48.2 GFLOPs
#
# Transferred 475/481 items from yolov5m.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.0005), 82 bias
# train: Scanning /media/roger/Datos/asignaturas_master/tfm/detector_personas/yolo
# train: 52.7GB RAM required, 21.5/31.0GB available, not caching images ⚠️
# val: Scanning /media/roger/Datos/asignaturas_master/tfm/detector_personas/yolov5
# val: Caching images (2.2GB ram): 100%|██████████| 2693/2693 [00:01<00:00, 2162.6
#
# AutoAnchor: 4.42 anchors/target, 0.997 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/exp4/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to yolov5/runs/train/exp4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/49      5.79G    0.04777    0.03606          0         26        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.821      0.706      0.799      0.536
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/49      5.62G    0.03966     0.0346          0         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.799      0.702      0.786      0.525
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/49      5.62G    0.04067    0.03659          0         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.811      0.674      0.769      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/49      5.62G    0.04104    0.03772          0         26        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.817      0.688      0.788      0.521
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/49      5.62G    0.03994     0.0369          0         24        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.826       0.69      0.793      0.535
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/49      5.62G    0.03922    0.03658          0         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.818        0.7      0.799      0.543
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/49      5.62G    0.03879    0.03618          0         16        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.821      0.705      0.803      0.548
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/49      5.62G    0.03839    0.03598          0         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.833      0.705      0.808      0.555
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/49      6.14G      0.038    0.03571          0         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.828      0.711      0.812       0.56
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/49      6.14G    0.03786    0.03555          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.835      0.709      0.813      0.563
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/49      6.14G    0.03771    0.03527          0          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.829      0.719      0.816      0.565
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/49      6.14G    0.03745     0.0352          0         26        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.829       0.72      0.817      0.568
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/49      6.14G    0.03729    0.03492          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004       0.84      0.715      0.818      0.569
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/49      6.14G    0.03719    0.03482          0         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.843      0.715       0.82      0.571
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/49      6.14G    0.03703    0.03476          0         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.839      0.718       0.82      0.572
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/49      6.14G    0.03687    0.03476          0         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.839      0.719      0.821      0.573
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/49      6.14G    0.03674    0.03455          0         40        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.838      0.719      0.821      0.573
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/49      6.14G     0.0367    0.03454          0         32        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.838      0.721      0.822      0.574
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/49      6.14G     0.0365    0.03439          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.839      0.722      0.822      0.575
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/49      6.14G    0.03635    0.03432          0         34        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.836      0.723      0.823      0.575
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/49      6.14G    0.03628    0.03409          0         36        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.842       0.72      0.823      0.575
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/49      6.14G    0.03616    0.03426          0         34        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.842      0.719      0.823      0.576
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/49      6.14G    0.03597    0.03388          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.836      0.724      0.823      0.577
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/49      6.14G    0.03598    0.03403          0         14        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.835      0.726      0.824      0.578
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/49      6.14G    0.03578    0.03378          0         22        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.839      0.723      0.824      0.578
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/49      6.14G    0.03568     0.0337          0         25        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.836      0.724      0.824      0.579
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/49      6.14G    0.03551    0.03339          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.835      0.726      0.824       0.58
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/49      6.14G    0.03541    0.03355          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.832      0.727      0.825       0.58
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/49      6.14G    0.03525    0.03325          0         39        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004       0.83      0.729      0.825      0.581
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/49      6.14G    0.03508    0.03314          0         16        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.828      0.732      0.826      0.582
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/49      6.14G    0.03487    0.03297          0         22        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.827      0.734      0.826      0.582
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/49      6.14G     0.0348    0.03269          0         15        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.834      0.728      0.826      0.583
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/49      6.14G    0.03465    0.03276          0         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.837      0.726      0.827      0.584
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/49      6.14G    0.03454    0.03256          0         29        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.839      0.724      0.827      0.584
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/49      6.14G    0.03431    0.03228          0         21        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.839      0.726      0.828      0.585
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/49      6.14G    0.03419    0.03225          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.842      0.725      0.827      0.585
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/49      6.14G      0.034    0.03225          0         12        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.841      0.725      0.828      0.586
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/49      6.14G    0.03384    0.03195          0         37        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.839      0.727      0.828      0.586
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/49      6.14G     0.0337    0.03175          0         36        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.836      0.729      0.828      0.586
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/49      6.14G    0.03357    0.03154          0         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004       0.84      0.727      0.828      0.586
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/49      6.14G    0.03341    0.03152          0         16        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.841      0.727      0.829      0.587
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/49      6.14G    0.03323     0.0311          0         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.841      0.727      0.829      0.587
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/49      6.14G      0.033    0.03122          0         35        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.843      0.726      0.829      0.588
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/49      6.14G    0.03279    0.03084          0          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.838      0.731       0.83      0.587
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/49      6.14G    0.03252    0.03043          0         15        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.831      0.736       0.83      0.588
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/49      6.14G    0.03225    0.03036          0         20        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004       0.83      0.737       0.83      0.588
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/49      6.14G    0.03211    0.03017          0         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.833      0.736       0.83      0.588
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/49      6.14G    0.03178    0.02972          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.837      0.733       0.83      0.589
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/49      6.14G    0.03157    0.02965          0         36        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.837      0.735       0.83      0.589
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/49      6.14G    0.03132    0.02926          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.838      0.732      0.829      0.589
#
# 50 epochs completed in 14.127 hours.
# Optimizer stripped from yolov5/runs/train/exp4/weights/last.pt, 42.1MB
# Optimizer stripped from yolov5/runs/train/exp4/weights/best.pt, 42.1MB
#
# Validating yolov5/runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all       2693      11004      0.839      0.733      0.829      0.589
# Results saved to yolov5/runs/train/exp4

# %% [markdown]
# #### Los resultados obtenidos entrenando 50 épocas son bastante buenos

# %% [markdown]
# #### Cargamos el modelo de detección con el mejor de los pesos

# %%
modelo = torch.hub.load('ultralytics/yolov5','custom',path='./yolov5/runs/train/exp/weights/best.pt')
# Out:
# Using cache found in /home/roger/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-3-31 Python-3.10.13 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7940MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# Adding AutoShape...

# %% [markdown]
# #### Definimos funciones para la detección

# %%
import subprocess

def deteccion_imagen(ruta):
    imagen = cv2.imread(ruta)
    imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

    detect=model(imagen_rgb)
    foto = np.squeeze(detect.render())

    plt.imshow(foto)
    plt.show()


#detección de video completo usando el script detect.py del repositorio de github

def deteccion_video(ruta_video, umbral_confianza = 0.25,umbral_iou = 0.45):
    comando = [
        "python", "./yolov5/detect.py",
        "--weights", "./yolov5/runs/train/exp/weights/best.pt",
        "--img", "640",
        "--conf", str(umbral_confianza),
        "--iou-thres", str(umbral_iou),
        "--source", ruta_video
    ]
    
    # Ejecutar el comando
    subprocess.run(comando)
    
    #!python ./yolov5/detect.py --weights './yolov5/runs/train/exp/weights/best.pt' --img 640 --conf 0.25 --source ruta

# %% [markdown]
# #### Hacemos la detección sobre dos vídeo . Los resultados son buenos

# %%
ruta_video_1 = os.path.join(ruta_actual,"surfistas.mp4")
ruta_video_2 = os.path.join(ruta_actual,"familia.mp4")

#detección en el vídeo de los surfistas
deteccion_video(ruta_video_1, umbral_confianza = 0.25,umbral_iou = 0.45)

#detección en el vídeo de la pareja con niño
deteccion_video(ruta_video_2, umbral_confianza = 0.25,umbral_iou = 0.45)

#Los vídeos con las detecciones se almacenan en ./yolov5/runs/detect
#Se observa que los resultados son buenos
# Out:
# detect: weights=['./yolov5/runs/train/exp/weights/best.pt'], source=/media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-353-g5eca7b9c Python-3.10.13 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7940MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 44.0ms
# video 1/1 (2/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (3/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (4/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (5/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (6/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (7/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (8/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (9/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (10/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (11/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (12/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (13/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (14/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (15/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (16/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (17/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (18/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (19/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (20/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (21/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (22/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (23/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (24/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (25/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (26/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (27/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (28/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (29/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (30/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (31/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (32/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (33/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (34/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (35/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (36/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (37/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (38/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (39/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (40/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (41/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (42/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (43/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (44/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (45/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (46/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (47/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (48/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (49/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (50/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (51/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (52/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (53/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (54/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.5ms
# video 1/1 (55/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (56/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (57/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (58/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (59/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (60/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (61/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (62/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (63/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (64/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (65/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (66/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (67/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (68/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (69/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (70/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (71/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (72/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (73/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (74/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (75/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (76/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (77/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (78/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (79/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (80/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (81/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (82/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (83/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (84/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (85/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (86/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (87/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (88/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (89/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (90/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (91/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (92/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (93/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (94/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (95/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (96/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (97/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (98/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (99/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (100/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (101/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (102/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (103/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (104/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (105/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (106/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (107/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (108/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (109/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (110/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 3 personas, 4.4ms
# video 1/1 (111/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 4 personas, 4.4ms
# video 1/1 (112/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 3 personas, 4.4ms
# video 1/1 (113/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 3 personas, 4.4ms
# video 1/1 (114/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 3 personas, 4.4ms
# video 1/1 (115/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (116/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (117/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (118/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (119/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (120/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (121/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (122/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (123/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (124/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (125/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (126/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (127/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (128/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (129/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (130/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (131/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (132/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (133/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (134/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (135/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (136/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (137/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (138/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (139/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (140/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (141/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (142/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (143/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (144/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (145/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (146/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (147/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (148/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (149/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (150/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (151/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (152/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (153/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (154/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (155/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (156/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (157/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (158/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (159/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (160/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (161/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (162/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (163/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (164/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (165/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (166/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (167/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (168/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (169/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (170/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (171/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (172/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (173/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (174/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (175/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (176/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (177/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (178/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 3 personas, 4.4ms
# video 1/1 (179/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (180/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 3 personas, 4.4ms
# video 1/1 (181/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (182/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (183/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (184/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (185/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (186/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (187/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (188/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (189/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (190/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (191/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (192/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (193/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (194/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (195/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (196/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (197/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (198/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# video 1/1 (199/199) /media/roger/Datos/asignaturas_master/tfm/detector_personas/surfistas.mp4: 384x640 2 personas, 4.4ms
# Speed: 0.3ms pre-process, 4.6ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp
# detect: weights=['./yolov5/runs/train/exp/weights/best.pt'], source=/media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-353-g5eca7b9c Python-3.10.13 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 7940MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 40.8ms
# video 1/1 (2/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (3/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (4/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (5/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (6/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (7/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (8/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (9/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (10/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (11/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (12/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (13/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (14/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (15/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (16/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (17/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (18/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (19/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (20/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (21/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (22/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (23/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (24/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (25/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (26/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (27/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (28/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (29/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (30/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 2 personas, 4.3ms
# video 1/1 (31/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (32/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (33/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (34/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (35/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (36/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (37/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (38/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (39/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (40/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (41/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (42/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (43/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (44/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (45/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (46/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (47/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (48/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (49/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (50/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (51/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (52/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (53/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (54/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (55/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (56/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (57/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (58/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (59/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (60/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (61/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (62/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (63/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (64/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (65/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (66/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (67/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (68/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (69/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (70/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (71/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (72/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (73/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (74/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (75/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (76/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (77/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (78/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (79/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (80/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (81/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (82/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (83/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (84/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (85/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (86/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (87/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (88/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (89/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (90/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (91/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (92/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (93/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (94/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (95/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (96/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (97/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (98/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (99/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (100/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (101/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (102/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (103/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (104/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (105/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (106/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (107/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (108/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (109/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (110/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (111/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (112/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (113/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (114/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (115/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (116/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (117/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (118/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (119/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (120/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (121/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (122/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (123/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (124/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (125/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (126/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (127/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (128/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (129/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (130/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (131/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (132/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (133/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (134/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (135/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (136/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (137/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (138/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (139/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (140/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (141/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (142/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (143/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (144/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (145/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (146/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (147/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (148/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (149/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (150/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (151/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (152/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (153/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (154/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (155/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (156/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (157/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (158/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (159/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (160/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (161/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (162/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (163/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (164/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (165/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (166/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (167/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (168/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (169/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (170/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (171/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (172/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (173/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 6.1ms
# video 1/1 (174/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (175/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (176/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (177/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (178/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (179/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (180/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (181/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (182/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (183/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (184/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (185/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (186/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (187/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (188/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (189/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (190/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (191/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (192/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (193/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (194/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (195/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (196/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (197/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (198/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (199/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (200/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (201/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (202/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (203/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (204/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (205/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (206/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (207/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (208/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (209/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (210/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (211/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (212/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (213/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (214/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (215/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (216/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (217/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (218/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (219/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (220/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (221/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (222/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (223/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (224/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (225/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (226/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (227/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (228/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (229/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (230/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (231/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (232/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (233/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (234/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (235/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (236/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (237/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (238/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (239/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (240/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (241/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (242/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (243/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# video 1/1 (244/244) /media/roger/Datos/asignaturas_master/tfm/detector_personas/familia.mp4: 640x384 3 personas, 4.3ms
# Speed: 0.2ms pre-process, 4.4ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp2
